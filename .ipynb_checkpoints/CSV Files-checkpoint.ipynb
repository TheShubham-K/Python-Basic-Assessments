# %%
with open("scarlet", "r") as f:
    lines_list = f.readlines()
    for line in lines_list:
        print("line read: " + line)
# Out:
# line read: The name gives you personality that is mature, confident and practical.
#
# line read: The responsible nature is equally versatile and has great conversational abilities. You can pick any topic and have a meaningful conversation on it.
#
# line read: It is this versatile nature that allows you take initiatives and gives leadership abilities.
#
# line read: Having said that, you often end up showing a know-it-all attitude, even when it's best to sit back, watch and learn.
#
# line read: This is is something you need to take the guard off, as others may perceive you as headstrong or overpowering.
#
# line read: The name also gifts you many creative and artistic skills. This could be through ability to write, in performing or visual arts.
#
# line read: With strong parental instincts, you are a person who is visibly affectionate to your dear ones. Keeping the bond of love intact is of utmost importance to you.
#
# ...
